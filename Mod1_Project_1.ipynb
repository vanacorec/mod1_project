# %%
import pandas as pd
import time
import requests
import numpy as np



caroline_client_id = '7IEQi7lfXRjmtDJLNvgMyA' 
caroline_api_key = 'r1M9ZrmSeg7AOyO0AbaWsUJS9Gpp4qahPXhiinQ7xPNqWAjr4X-Esq_7GEGOIqxvNZ26NSNGiaOEuxU_I5BHRXQyHRHglftCgMqfXB_TgnBLc3xeHngR5hKHpXlcXHYx' 

luke_client_id = 'tE7T-Ahc0yXhWwmHIrO-Gg'
luke_api_key = 'p07EFWIaSoiEm_X6Rl4ipxVsqY_TagLajN4QU7FGstq-v1N2MOMc738agKYFMUABFUzja_t-n1FQN3rOoOaEzxJ2XP3sijqsI-xqzhmu_tA6oFf-NDy46KRCmmFcXHYx'

 

    
def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    return response





def all_results(url_params, api_key):
    # first call
 
    response = yelp_call(url_params, api_key)
    total = response.json()['total']

    
    print('{} total matches found.'.format(total))
    
    
    
    cur = 50
    
    dfs = response.json()['businesses']
    
    while cur < total and cur < 150:
        url_params['offset'] = cur
        dfs.append(yelp_call(url_params, api_key).json()['businesses'])
        time.sleep(1) #Wait a second
        cur += 50
    df = pd.concat(np.array(dfs), ignore_index=True)
    return df


term = 'sushi'
location = 'Astoria NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50
             }

x = all_results(url_params, caroline_api_key)

x
# Out:
# 449 total matches found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-ab8391dbfe06> in <module>()
#      56              }
#      57
# ---> 58 x = all_results(url_params, caroline_api_key)
#      59
#      60 x
#
# <ipython-input-54-ab8391dbfe06> in all_results(url_params, api_key)
#      45         time.sleep(1) #Wait a second
#      46         cur += 50
# ---> 47     df = pd.concat(np.array(dfs), ignore_index=True)
#      48     return df
#      49
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
# ...

# %%
##### import pandas as pd
import time
import requests
import numpy as np



caroline_client_id = '7IEQi7lfXRjmtDJLNvgMyA' 
caroline_api_key = 'r1M9ZrmSeg7AOyO0AbaWsUJS9Gpp4qahPXhiinQ7xPNqWAjr4X-Esq_7GEGOIqxvNZ26NSNGiaOEuxU_I5BHRXQyHRHglftCgMqfXB_TgnBLc3xeHngR5hKHpXlcXHYx' 

luke_client_id = 'tE7T-Ahc0yXhWwmHIrO-Gg'
luke_api_key = 'p07EFWIaSoiEm_X6Rl4ipxVsqY_TagLajN4QU7FGstq-v1N2MOMc738agKYFMUABFUzja_t-n1FQN3rOoOaEzxJ2XP3sijqsI-xqzhmu_tA6oFf-NDy46KRCmmFcXHYx'





def get_all_results(url_parameters, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    print(url_parameters)
    
    response = requests.get(url, headers=headers, params=url_parameters)
    print(response)
    
    total = response.json()['total']
    print(total)
    
    business_list = response.json()['businesses']
    
    current = 50
    
    while current < total and current < 1000:
        url_parameters['offset'] = current
        
        print(url_parameters)
        
        response = requests.get(url, headers=headers, params=url_parameters)
        
        for business in response.json()['businesses']:
            business_list.append(business)
        
        time.sleep(1) #Wait a second
        current += 50
    
    return pd.DataFrame(business_list)
    
    


term = 'Restaurants'
location = 'Financial District, Manhattan, NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50,
                'price' : 4
             }



results_price4 = get_all_results(url_params, luke_api_key)
print(results_price4.shape)
results_price4
# Out:
# {'term': 'Restaurants', 'location': 'Financial+District,+Manhattan,+NY', 'limit': 50, 'price': 4}
# <Response [200]>
# 43
# (43, 16)
#                                                alias  \
# 0                                  manhatta-new-york
# 1                                delmonicos-new-york
# 2                   markjoseph-steakhouse-new-york-2
# 3                             momofuku-ko-new-york-3
# 4                                  l-appart-new-york
# 5                                   jungsik-new-york
# 6                             nobu-downtown-new-york
# 7                               reserve-cut-new-york
# 8                          the-river-café-brooklyn-3
# 9                        shabushabu-macoron-new-york
# 10                                  carbone-new-york
# 11                                le-coucou-new-york
# 12                                     kura-new-york
# 13                   cipriani-wall-street-new-york-2
# ...

# %%
results2.tail()
# Out:
#                             alias  \
# 45     veronicas-kitchen-new-york
# 46             distilled-new-york
# 47            dark-horse-new-york
# 48           il-brigante-new-york
# 49  the-hideaway-seaport-new-york
#
#                                            categories  \
# 45  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...
# 46  [{'alias': 'newamerican', 'title': 'American (...
# 47  [{'alias': 'tradamerican', 'title': 'American ...
# 48         [{'alias': 'italian', 'title': 'Italian'}]
# 49  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
#
#                                           coordinates   display_phone  \
# 45  {'latitude': 40.7056045963693, 'longitude': -7...  (917) 848-2465
# 46  {'latitude': 40.7189994, 'longitude': -74.0062...  (646) 809-9490
# 47   {'latitude': 40.713718, 'longitude': -74.008036}  (212) 608-3900
# 48   {'latitude': 40.707492, 'longitude': -74.002571}  (212) 285-0222
# 49  {'latitude': 40.7080634, 'longitude': -74.002083}  (212) 385-2222
#
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#     100% |████████████████████████████████| 174kB 6.1MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for openpyxl ... done
#   Stored in directory: /Users/carolinevanacore/Library/Caches/pip/wheels/5a/de/77/f07186146bd0337342dd8c86fa12441f4f9c59573c51dcce9d
#   Running setup.py bdist_wheel for et-xmlfile ... done
#   Stored in directory: /Users/carolinevanacore/Library/Caches/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# ...
# You are using pip version 10.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
results_price1.to_csv("results_price1.csv")

# %%
fidi_zipcodes = [10004, 10005, 10006, 10038]

# %%
results_price4.to_csv("results_price4.csv")

# %%
results_price1
# Out:
#                                                alias  \
# 0                            bao-bao-cafe-new-york-3
# 1     white-horse-tavern-financial-district-new-york
# 2                         veronicas-kitchen-new-york
# 3                            go-go-curry-new-york-10
# 4                 roti-modern-mediterranean-new-york
# 5                          stage-door-pizza-new-york
# 6                              luckyim-thai-new-york
# 7                                   naya-new-york-20
# 8                           sakura-of-japan-new-york
# 9                                  tomorrow-new-york
# 10                           iron-horse-nyc-new-york
# 11                wah-fung-no-1-fast-food-new-york-3
# 12                        underground-pizza-new-york
# 13                         chens-buffet-bar-new-york
# 14                       sams-falafel-stand-new-york
# 15                                 kopitiam-new-york
# 16              88-lan-zhou-handmade-noodle-new-york
# ...

# %%
all_results = pd.concat([results_price1, results_price2, results_price3, results_price4], ignore_index = True)

# %%
all_results.shape
# Out:
# (1917, 16)

# %%
results_price1.shape[0]+ results_price2.shape[0]+ results_price3.shape[0]+ results_price4.shape[0]
# Out:
# 1917

# %%
all_results.describe()
# Out:
#            distance       rating  review_count
# count   1917.000000  1917.000000   1917.000000
# mean    1740.889783     3.662233    271.116328
# std     3241.221494     0.628169    480.626752
# min       19.458771     1.000000      1.000000
# 25%      872.273734     3.500000     41.000000
# 50%     1579.289711     3.500000    137.000000
# 75%     2189.084346     4.000000    334.000000
# max    91442.115735     5.000000  10627.000000

# %%
foodtypes = []
for row in all_results['categories']:
    ft = []
    for foodtype in row:
        ft.append(foodtype['alias'])
    foodtypes.append(ft)
    #for food_type in all_results['categories'][index][0]['alias'])
    
foodtypes
# Out:
# [['noodles', 'chinese'],
#  ['pubs', 'burgers', 'venues'],
#  ['soulfood', 'foodstands', 'trinidadian'],
#  ['japacurry'],
#  ['mediterranean'],
#  ['pizza'],
#  ['foodtrucks', 'thai'],
#  ['lebanese', 'mediterranean'],
#  ['japanese', 'foodstands'],
#  ['chinese'],
#  ['divebars', 'burgers'],
#  ['chinese', 'hotdogs', 'noodles'],
#  ['pizza', 'italian'],
#  ['chinese'],
#  ['falafel', 'foodtrucks'],
#  ['malaysian', 'singaporean'],
#  ['chinese', 'noodles'],
#  ['pizza', 'italian'],
#  ['divebars', 'seafood', 'pubs'],
#  ['sandwiches', 'italian'],
#  ['puertorican', 'foodstands'],
#  ['chinese', 'burgers', 'noodles'],
#  ['desserts', 'portuguese', 'cafes'],
#  ['indpak', 'foodstands', 'bangladeshi'],
#  ['himalayan'],
#  ['italian'],
#  ['chinese', 'noodles'],
#  ['taiwanese', 'chinese', 'noodles'],
#  ['foodtrucks', 'indpak'],
#  ['coffee', 'gluten_free', 'breakfast_brunch'],
#  ['chinese'],
#  ['chinese', 'noodles'],
#  ['chinese'],
#  ['vietnamese'],
# ...

# %%
filtered
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#         ..
# 1887   NaN
# 1888   NaN
# 1889   NaN
# 1890   NaN
# 1891   NaN
# 1892   NaN
# 1893   NaN
# 1894   NaN
# 1895   NaN
# 1896   NaN
# 1897   NaN
# 1898   NaN
# 1899   NaN
# 1900   NaN
# 1901   NaN
# 1902   NaN
# 1903   NaN
# 1904   NaN
# 1905   NaN
# 1906   NaN
# 1907   NaN
# 1908   NaN
# 1909   NaN
# 1910   NaN
# 1911   NaN
# 1912   NaN
# 1913   NaN
# 1914   NaN
# 1915   NaN
# 1916   NaN
# Name: categories, Length: 1917, dtype: float64
